# %%
import pickle
import cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
dist_pickle = pickle.load( open( "wide_dist_pickle.p", "rb" ) )
objpoints = dist_pickle["objpoints"]
imgpoints = dist_pickle["imgpoints"]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-660f3ae320f1> in <module>
# ----> 1 dist_pickle = pickle.load( open( "wide_dist_pickle.p", "rb" ) )
#       2 objpoints = dist_pickle["objpoints"]
#       3 imgpoints = dist_pickle["imgpoints"]
#
# FileNotFoundError: [Errno 2] No such file or directory: 'wide_dist_pickle.p'

# %%
img = mpimg.imread(r'C:\Users\Yunita Elisabet\OneDrive\Dokumen\semester 4\citra digital\chess.jpg')
plt.imshow(img)

# %%
criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 30, 0.001)

# %%
objp = np.zeros((6*7,3), np.float32)
objp[:,:2] = np.mgrid[0:7,0:6].T.reshape(-1,2)

# %%
objpoints = [] # 3d point in real world space
imgpoints = [] # 2d points in image plane.

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
ret, corners = cv2.findChessboardCorners(img_gray, (8,6), None)

# %%
if ret == True:
    imgpoints.append(corners)
    objpoints.append(objp)

# %%
if ret == True:
    imgpoints.append(corners)
    objpoints.append(objp)

# %%
img = cv2.drawChessboardCorners(img, (8,6), corners, ret)
plt.imshow(img)

# %%
import pickle

# %%
dist_pickle = pickle.load( open( r"C:\Users\Yunita Elisabet\OneDrive\Dokumen\semester 4\citra digital\wide_dist_pickle.p", "rb" ) )

# %%
objpoints = dist_pickle["objpoints"]
imgpoints = dist_pickle["imgpoints"]

# %%
def cal_undistort(img, objpoints, imgpoints):
    ret, mtx, dist, rvecs, tvecs = cv2.calibrateCamera(objpoints, imgpoints, img.shape[:2], None, None)
    undist = cv2.undistort(img, mtx, dist, None, mtx)
    return undist

# %%
undistorted = cal_undistort(img, objpoints, imgpoints)

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(24, 9))
f.tight_layout()
ax1.imshow(img)
ax1.set_title('Original Image', fontsize=50)
ax2.imshow(undistorted)
ax2.set_title('Undistorted Image', fontsize=50)
plt.subplots_adjust(left=0., right=1, top=0.9, bottom=0.)

# %%
ret, mtx, dist, rvecs, tvecs = cv2.calibrateCamera(objpoints, imgpoints, img_gray.shape[::-1], None, None)

# %%
print(mtx)
# Out:
# [[560.33468243   0.         651.26269237]
#  [  0.         561.37973145 499.06652492]
#  [  0.           0.           1.        ]]

# %%
print(dist)
# Out:
# [[-2.32951777e-01  6.17256346e-02 -1.83274570e-05  3.39255772e-05
#   -7.54987702e-03]]

# %%
print(rvecs)
# Out:
# [array([[ 0.09308084],
#        [-0.32464563],
#        [-0.02490234]]), array([[ 0.11260196],
#        [-0.18662517],
#        [-0.03802293]]), array([[ 0.05157993],
#        [ 0.02649835],
#        [-0.01095279]]), array([[ 0.14101626],
#        [-0.03899637],
#        [ 0.00317132]]), array([[0.08922158],
#        [0.28760296],
#        [0.00591943]]), array([[0.14841607],
#        [0.19129028],
#        [0.03749722]]), array([[ 0.29552223],
#        [-0.39705337],
#        [-0.20158414]]), array([[ 0.45379007],
#        [-0.05701789],
#        [-0.01006259]]), array([[ 0.34138088],
#        [-0.02711319],
#        [-0.01567581]]), array([[ 0.11145999],
#        [-0.05243041],
#        [-0.01676855]]), array([[ 0.1556634 ],
#        [-0.33453338],
#        [-0.05607821]]), array([[ 0.08917102],
#        [-0.10633331],
#        [-0.0594088 ]]), array([[ 0.1088744 ],
#        [-0.04830814],
#        [ 0.02251646]]), array([[0.29215972],
#        [0.1955582 ],
# ...

# %%
print(tvecs)
# Out:
# [array([[-1.56149622],
#        [-2.78556269],
#        [ 4.06279466]]), array([[-2.10062505],
#        [-2.81566351],
#        [ 5.97223987]]), array([[-3.50018044],
#        [-2.74879888],
#        [ 3.71756178]]), array([[-3.42974697],
#        [-2.17466723],
#        [ 3.4425157 ]]), array([[-4.02834793],
#        [-2.47123871],
#        [ 4.56915544]]), array([[-4.57135431],
#        [-1.98805332],
#        [ 4.41004635]]), array([[-2.26259909],
#        [-1.45961934],
#        [ 2.56440984]]), array([[-3.12594056],
#        [-0.99588848],
#        [ 2.71049019]]), array([[-3.05862424],
#        [-1.4123842 ],
#        [ 2.69191729]]), array([[-3.59908193],
#        [-2.69512373],
#        [ 7.04366115]]), array([[-0.8191811 ],
#        [-2.90003603],
#        [ 7.39255198]]), array([[ 1.73479211],
#        [-2.55490736],
#        [ 5.17133078]]), array([[-6.36192132],
#        [-2.36449564],
#        [ 4.38172068]]), array([[-4.86065048],
#        [-1.75192218],
# ...

# %%
print(ret)
# Out:
# 0.5662874944101884
